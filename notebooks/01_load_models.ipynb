# %% [markdown]
# # 01 - Load Models
#
# Load representative models before importing them into TVM.

# %%
import sys
from pathlib import Path

EXAMPLES = Path.cwd() / 'examples' / 'python'
if str(EXAMPLES) not in sys.path:
    sys.path.insert(0, str(EXAMPLES))

# %%
from tvm_prep.model_zoo import load_pytorch_model, load_tensorflow_model

pytorch_model = load_pytorch_model('resnet18')
tf_model = load_tensorflow_model('mobilenet_v2')

print(pytorch_model)
print(tf_model)

# %% [markdown]
# For ONNX and TFLite, use `examples/python/compile_model.py --model-path ...` with the exact input name and shape for your file.
