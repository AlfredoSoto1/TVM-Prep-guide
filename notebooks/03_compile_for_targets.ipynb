# %% [markdown]
# # 03 - Compile For Targets
#
# Select a target profile and build a TVM library.

# %%
import sys
from pathlib import Path

EXAMPLES = Path.cwd() / 'examples' / 'python'
if str(EXAMPLES) not in sys.path:
    sys.path.insert(0, str(EXAMPLES))

from tvm_prep.targets import TARGET_PROFILES

for name, profile in TARGET_PROFILES.items():
    print(name, '=>', profile.target)

# %%
# Change this to raspi4_aarch64, raspi_armv7, wasm32, vulkan, or c as needed.
TARGET_PROFILE = 'x86_64'
MODEL = 'resnet18'
FRONTEND = 'pytorch'
print(TARGET_PROFILE, MODEL, FRONTEND)
